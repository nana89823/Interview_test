# %%
import pandas as pd

# %%
pd.set_option("display.max_columns",30)
pd.set_option("display.max_rows",1000)

# %%
dfB = pd.read_csv("品項B銷售.csv",)
dfB
# Out:
#      店家代號  2022年1月  2022年2月  2022年3月  2022年4月  2022年5月  2022年6月  2022年7月  \
# 0       1        0        0        0        0        3        0        4
# 1       2        7        0        8        0        0        0        0
# 2       3       10        4       20       10       15       10       15
# 3       4       10        0       10        0       20       20        0
# 4       5        0       10        0        0        0       10        0
# 5       6       20        0        0       50        0        0        0
# 6       7       30       10       20       60        0        0        0
# 7       8        0        0      140        0        0        0       20
# 8       9        0        0        0       10        0        0        0
# 9      10       10        0       20       25        0        0        0
# 10     11        0        0        2        2        0        0        2
# 11     12        0       10        0        5        0        0        0
# ...

# %%
dfB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 901 entries, 0 to 900
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   店家代號      901 non-null    int64
#  1   2022年1月   901 non-null    int64
#  2   2022年2月   901 non-null    int64
#  3   2022年3月   901 non-null    int64
#  4   2022年4月   901 non-null    int64
#  5   2022年5月   901 non-null    int64
#  6   2022年6月   901 non-null    int64
#  7   2022年7月   901 non-null    int64
#  8   2022年8月   901 non-null    int64
#  9   2022年9月   901 non-null    int64
#  10  2021年1月   901 non-null    int64
#  11  2021年2月   901 non-null    int64
#  12  2021年3月   901 non-null    int64
#  13  2021年4月   901 non-null    int64
#  14  2021年5月   901 non-null    int64
#  15  2021年6月   901 non-null    int64
#  16  2021年7月   901 non-null    int64
#  17  2021年8月   901 non-null    int64
#  18  2021年9月   901 non-null    int64
#  19  2021年10月  901 non-null    int64
# ...

# %%
dfB.describe()
# Out:
#              店家代號     2022年1月     2022年2月      2022年3月      2022年4月  \
# count  901.000000  901.000000  901.000000   901.000000   901.000000
# mean   471.117647    5.228635    8.643729    16.456160    38.866815
# std    274.826668   18.290219   34.053465    61.646136   180.558855
# min      1.000000    0.000000    0.000000   -10.000000     0.000000
# 25%    234.000000    0.000000    0.000000     0.000000     0.000000
# 50%    467.000000    0.000000    0.000000     0.000000     3.000000
# 75%    706.000000    3.000000    8.000000    10.000000    16.000000
# max    956.000000  310.000000  600.000000  1000.000000  3800.000000
#
#           2022年5月     2022年6月     2022年7月     2022年8月     2022年9月     2021年1月  \
# count  901.000000  901.000000  901.000000  901.000000  901.000000  901.000000
# mean     0.960044    3.374029    3.097669    3.744728    3.012209    4.051054
# std     27.719840   11.252306    9.226376   11.333004    9.728473   15.891845
# ...

# %%
dfB[dfB.loc[:,"2022年5月"]<0]
# Out:
#      店家代號  2022年1月  2022年2月  2022年3月  2022年4月  2022年5月  2022年6月  2022年7月  \
# 402   416        0        0       60      830     -220        0        0
# 714   748        0        0        0        0      -30        0        0
# 786   829        0        0        0     1618     -768        0        0
# 815   860        0        0        0       11       -1        0        0
#
#      2022年8月  2022年9月  2021年1月  2021年2月  2021年3月  2021年4月  2021年5月  2021年6月  \
# 402        0        0       20       20       37       70       40       70
# 714        0        0        0        8        0        0        0       40
# 786        0        0        0       30       20       30       30       20
# 815       30        0        0        0        0        0        0        0
#
#      2021年7月  2021年8月  2021年9月  2021年10月  2021年11月  2021年12月
# 402      200      150        0         0        39       100
# 714        0        0        0         0         0         0
# ...

# %%
dfB[dfB.loc[:,"2021年9月"]<0]
# Out:
#     店家代號  2022年1月  2022年2月  2022年3月  2022年4月  2022年5月  2022年6月  2022年7月  \
# 63    66      310      120      480      930        0        0        0
#
#     2022年8月  2022年9月  2021年1月  2021年2月  2021年3月  2021年4月  2021年5月  2021年6月  \
# 63        0        0       20       30      160      490      250      100
#
#     2021年7月  2021年8月  2021年9月  2021年10月  2021年11月  2021年12月
# 63      150      980     -300         0       160         0

# %%
totalByY_2021 = dfB.loc[:,"2021年1月":].sum().sum()
totalByM_2021 = dfB.loc[:,"2021年1月":].sum()
totalByM_1_9_2021 = dfB.loc[:,"2021年1月":"2021年9月"].sum().sum()
print(f'2021年各月份的銷售額:\n{totalByM_2021}')
print("------")
print(f'2021年總共的銷售額:\n{totalByY_2021}')
print("------")
print(f'2021年1~9月的總銷售額:\n{totalByM_1_9_2021}')
# Out:
# 2021年各月份的銷售額:
# 2021年1月      3650
# 2021年2月      3527
# 2021年3月      3493
# 2021年4月     14279
# 2021年5月     11315
# 2021年6月     14055
# 2021年7月     10757
# 2021年8月      6902
# 2021年9月      3133
# 2021年10月     3840
# 2021年11月     4172
# 2021年12月     5709
# dtype: int64
# ------
# 2021年總共的銷售額:
# 84832
# ------
# 2021年1~9月的總銷售額:
# 71111

# %%
totalByY_1_9_2022 = dfB.loc[:,"2022年1月":"2022年9月"].sum()
totalByM_1_9_2022 = dfB.loc[:,"2022年1月":"2022年9月"].sum().sum()
print(f'2022年1~9月的銷售額:\n{totalByY_1_9_2022}')
print("------")
print(f'2021年1~9月的總銷售額:\n{totalByM_1_9_2022}')
# Out:
# 2022年1~9月的銷售額:
# 2022年1月     4711
# 2022年2月     7788
# 2022年3月    14827
# 2022年4月    35019
# 2022年5月      865
# 2022年6月     3040
# 2022年7月     2791
# 2022年8月     3374
# 2022年9月     2714
# dtype: int64
# ------
# 2021年1~9月的總銷售額:
# 75129

# %% [markdown]
# ### 品項B_2022與2021年的銷售額差距

# %% [markdown]
# ### 1-4月正成長 5-9月負成長

# %%
dfB.loc[:,"2022年1月":"2022年9月"].sum().values - dfB.loc[:,"2021年1月":"2021年9月"].sum().values
# Out:
# array([  1061,   4261,  11334,  20740, -10450, -11015,  -7966,  -3528,
#          -419], dtype=int64)

# %% [markdown]
# ### 品項B各家店2021~202209的銷售總量排名

# %%
dfB.loc[:,"2022年1月":].sum(axis=1).sort_values(ascending=False)
# Out:
# 708    10205
# 86      5030
# 63      3880
# 520     3850
# 711     3800
# 514     3141
# 709     2900
# 415     2380
# 489     2200
# 756     1850
# 416     1654
# 348     1630
# 537     1616
# 856     1570
# 292     1510
# 601     1500
# 608     1451
# 402     1416
# 349     1325
# 176     1268
# 338     1257
# 154     1244
# 197     1231
# 480     1210
# 786     1190
# 659     1180
# 345     1180
# 553     1151
# 151     1150
# 398     1145
# 114     1090
# 266     1010
# 19       972
# 216      920
# 7        901
# 715      900
# 57       900
# 667      890
# 868      860
# 141      850
# 392      825
# 387      821
# 54       785
# 713      780
# 182      766
# 124      740
# 27       715
# 265      702
# 215      695
# 643      683
# 336      673
# 122      670
# 583      668
# 746      625
# 134      600
# 890      600
# 542      600
# 66       590
# 46       570
# 42       560
# 179      555
# 759      545
# 785      535
# 753      534
# 170      524
# 564      517
# ...

# %% [markdown]
# ### 品項B各家店2021年的銷售總量排名

# %%
dfB.loc[:,"2021年1月":].sum(axis=1).sort_values(ascending=False)
# Out:
# 708    5400
# 86     2980
# 709    2900
# 520    2390
# 63     2040
# 711    1900
# 514    1743
# 608    1437
# 415    1180
# 489    1160
# 537    1134
# 176     938
# 856     880
# 348     880
# 601     870
# 345     750
# 402     746
# 398     675
# 349     660
# 480     660
# 553     659
# 197     648
# 643     569
# 7       561
# 216     560
# 114     550
# 667     540
# 387     531
# 154     529
# 392     525
# 266     510
# 659     500
# 83      480
# 215     453
# 338     451
# 57      450
# 19      432
# 46      430
# 265     422
# 124     400
# 713     400
# 182     396
# 141     390
# 122     380
# 868     360
# 542     360
# 27      345
# 583     344
# 66      340
# 786     340
# 785     340
# 166     320
# 134     320
# 336     318
# 388     313
# 890     310
# 735     310
# 198     305
# 151     305
# 416     293
# 179     290
# 861     280
# 6       280
# 50      270
# 753     269
# 756     260
# 170     260
# 474     260
# 67      260
# 401     260
# 564     257
# ...

# %% [markdown]
# ### 品項B各家店2021-202109的銷售總量排名

# %%
dfB.loc[:,"2021年1月":"2021年9月"].sum(axis=1).sort_values(ascending=False)
# Out:
# 708    4400
# 709    2900
# 86     2390
# 520    2240
# 711    1900
# 63     1880
# 514    1365
# 608    1324
# 415    1180
# 537     919
# 489     860
# 601     760
# 348     750
# 345     750
# 398     675
# 480     660
# 197     648
# 856     630
# 402     607
# 349     580
# 176     568
# 216     560
# 114     550
# 667     540
# 553     526
# 7       521
# 266     510
# 659     500
# 392     465
# 57      450
# 643     447
# 387     440
# 19      432
# 338     404
# 215     403
# 713     400
# 182     396
# 46      370
# 83      340
# 154     329
# 265     322
# 122     320
# 124     320
# 785     310
# 166     310
# 151     305
# 336     303
# 27      300
# 198     295
# 179     287
# 66      280
# 861     280
# 868     280
# 6       270
# 50      270
# 786     270
# 134     260
# 542     260
# 583     254
# 416     246
# 67      240
# 890     230
# 505     221
# 444     220
# 388     218
# 564     217
# 141     210
# 69      207
# 585     204
# 461     203
# 331     200
# ...

# %% [markdown]
# ### 品項B各家店2022-202209的銷售總量排名

# %%
dfB.loc[:,"2022年1月":"2022年9月"].sum(axis=1).sort_values(ascending=False)
# Out:
# 708    4805
# 86     2050
# 711    1900
# 63     1840
# 756    1590
# 292    1470
# 520    1460
# 514    1398
# 416    1361
# 415    1200
# 489    1040
# 786     850
# 151     845
# 338     806
# 348     750
# 154     715
# 715     700
# 856     690
# 659     680
# 402     670
# 349     665
# 601     630
# 54      615
# 197     583
# 480     550
# 19      540
# 114     540
# 266     500
# 868     500
# 553     492
# 537     482
# 398     470
# 141     460
# 57      450
# 746     435
# 345     430
# 759     423
# 713     380
# 182     370
# 27      370
# 216     360
# 336     355
# 539     351
# 667     350
# 7       340
# 42      340
# 124     340
# 446     330
# 176     330
# 583     324
# 524     319
# 546     310
# 392     300
# 387     290
# 122     290
# 890     290
# 69      289
# 206     288
# 134     280
# 265     280
# 434     280
# 813     278
# 884     270
# 179     265
# 272     265
# 753     265
# 170     264
# 564     260
# 66      250
# 401     250
# 215     242
# ...
