# %%
import pandas as pd
pd.set_option("display.max_columns",30)
pd.set_option("display.max_rows",6000)

# %%
df = pd.read_csv("大數據分析應用管理師_測試題目_林哲緯_0312 - data set.csv",header=None)
df = df.loc[2:,0:]
df.head()
# Out:
#     0     1        2        3        4        5        6        7        8   \
# 2   品項  店家代號  2022/01  2022/02  2022/03  2022/04  2022/05  2022/06  2022/07
# 3    A     1      NaN      NaN        4      NaN        5      NaN        5
# 4  NaN     2        5      NaN        5      NaN      NaN      NaN      NaN
# 5  NaN     3        5       10       50       10       30       10       30
# 6  NaN     4       20      NaN       20      NaN       30        0      NaN
#
#         9        10       11       12       13       14       15       16  \
# 2  2022/08  2022/09  2021/01  2021/02  2021/03  2021/04  2021/05  2021/06
# 3      NaN        2      NaN      NaN       10      NaN      NaN      NaN
# 4        5      NaN      NaN      NaN        5        5      NaN        6
# 5       15       10       15       20       20       35       20       27
# 6       40      NaN      NaN       20       10       20       10       20
#
#         17       18       19       20       21       22
# ...

# %%
df.dropna(subset=0)
# Out:
#       0     1        2        3        4        5        6        7        8   \
# 2     品項  店家代號  2022/01  2022/02  2022/03  2022/04  2022/05  2022/06  2022/07
# 3      A     1      NaN      NaN        4      NaN        5      NaN        5
# 914    B     1      NaN      NaN      NaN      NaN        3      NaN        4
# 1815   C     1      NaN      NaN        4      NaN        2      NaN        2
# 2702   D     1      NaN      NaN        2      NaN      NaN      NaN        1
# 3545   E     2        3      NaN        7      NaN      NaN      NaN      NaN
# 3800   F     2      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4361   G     3      NaN      NaN       13       14       20       -1       23
# 4966   H     3      NaN      NaN      NaN        4        1      NaN      NaN
#
#            9        10       11       12       13       14       15       16  \
# 2     2022/08  2022/09  2021/01  2021/02  2021/03  2021/04  2021/05  2021/06
# ...

# %% [markdown]
# + 品項A 3~913
# + 品項B 914~1814
# + 品項C 1815~2701
# + 品項D 2702~3544
# + 品項E 3545~3799
# + 品項F 3800~4360
# + 品項G 4361~4965
# + 品項H 4966~

# %%
df.loc[3:913,0]="A"
df.loc[914:1814,0]="B"
df.loc[1815:2701,0]="C"
df.loc[2702:3544,0]="D"
df.loc[3545:3799,0]="E"
df.loc[3800:4360,0]="F"
df.loc[4361:4965,0]="G"
df.loc[4966:,0]="H"

# %%
df = df.fillna(0)
df.head()
# Out:
#    0     1        2        3        4        5        6        7        8   \
# 2  品項  店家代號  2022/01  2022/02  2022/03  2022/04  2022/05  2022/06  2022/07
# 3   A     1        0        0        4        0        5        0        5
# 4   A     2        5        0        5        0        0        0        0
# 5   A     3        5       10       50       10       30       10       30
# 6   A     4       20        0       20        0       30        0        0
#
#         9        10       11       12       13       14       15       16  \
# 2  2022/08  2022/09  2021/01  2021/02  2021/03  2021/04  2021/05  2021/06
# 3        0        2        0        0       10        0        0        0
# 4        5        0        0        0        5        5        0        6
# 5       15       10       15       20       20       35       20       27
# 6       40        0        0       20       10       20       10       20
#
#         17       18       19       20       21       22
# ...

# %%
df1 = df.loc[2,0:]
# 把cloumns 名稱改為時間
df.columns= df1.tolist()

# %%
df = df.loc[3:,:]

# %%
df.head()
# Out:
#   品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 3  A    1       0       0       4       0       5       0       5       0
# 4  A    2       5       0       5       0       0       0       0       5
# 5  A    3       5      10      50      10      30      10      30      15
# 6  A    4      20       0      20       0      30       0       0      40
# 7  A    5       0      20       0      25      20      10       0      20
#
#   2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 3       2       0       0      10       0       0       0       0       0
# 4       0       0       0       5       5       0       6       5       0
# 5      10      15      20      20      35      20      27      21       0
# 6       0       0      20      10      20      10      20      20       0
# 7       0       0       0      10      10      10      10       0      20
#
#   2021/09 2021/10 2021/11 2021/12
# 3       0       0       0       0
# ...

# %% [markdown]
# # 品項各店離群值分析

# %% [markdown]
# ## 負成長

# %%
# A
dfA_negative = df.loc[(df["品項"] == "A") & (df["店家代號"].isin(["89","540","633","743"]))]
dfA_negative
# Out:
#     品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 91   A   89     350     800     600    1000       0       0       0       0
# 542  A  540       0       0      80     200       0       0       0      30
# 635  A  633       0       6       3      20       7       3       6       5
# 745  A  743       0       0       0     800       0       0       0       0
#
#     2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 91        0     470     150     230     760     450     640     700       0
# 542       0     180     140      65     245     230     180     390      40
# 635       5      52     185     250     209     213     518     358      13
# 745       0       0       0       0     300     100       0    2600       0
#
#     2021/09 2021/10 2021/11 2021/12
# 91        0     170     290     320
# 542     170       0       0       0
# 635      27     100     106      15
# 745       0       0       0       0

# %%
# B
dfB_negative = df.loc[(df["品項"] == "B") & (df["店家代號"].isin(["554","540","633","743"]))]
dfB_negative
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 1434  B  540      50     110     220    1020       0      40       0      20
# 1448  B  554       0       0       0       0      17       0       0       3
# 1522  B  633       0       0       2       6       0       0       1       3
# 1623  B  743       0       0       0       0       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 1434       0     220      80     150     340     450     220     620      40
# 1448       0       0       0       5       0       5       0       2       0
# 1522       2     102      60     200     142     221     397       0     202
# 1623       0       0       0       0     100     400       0    1800     600
#
#      2021/09 2021/10 2021/11 2021/12
# 1434     120       0      50     100
# 1448       6       0       3       3
# 1522       0      50      57       6
# 1623       0       0       0       0

# %%
# C
dfC_negative = df.loc[(df["品項"] == "C") & (df["店家代號"].isin(["89","225","429","540","633","742","743","745"]))]
dfC_negative
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 1901  C   89     200     400     800     600       0       0       0       0
# 2033  C  225      20      30     120     390       0       0       0       0
# 2233  C  429       0       0     400     200       0       0       0       0
# 2336  C  540       0       0      40      70       0       0       0      30
# 2427  C  633       0       2       8      17      12       0       4       3
# 2532  C  742       5       0       0    1400       0       0       0       0
# 2533  C  743       0       0     400    1800       0       0       0       0
# 2535  C  745      20     450     200     600       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 1901       0     410     120     300     490     250     600     500       0
# 2033       0       0       0       0     360     100       0     550       0
# ...

# %%
# D
dfD_negative = df.loc[(df["品項"] == "D") & (df["店家代號"].isin(["86","89","225","540","633","743","747","745"]))]
dfD_negative
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 2781  D   86       0       0       0       0       0       0       0       0
# 2784  D   89     100     200     600     400       0       0       0       0
# 2912  D  225      20      20      80     250       0       0       0       0
# 3206  D  540       0      20      40      30       0       0       0      20
# 3290  D  633       0       3       9      12       2      12       0       0
# 3386  D  743       0       0     200     600       0       0       0       0
# 3388  D  745      40     200     100     400       0       0       0       0
# 3390  D  747       0       0       0     100       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 2781       0       0      30      70      60      30      60       0       0
# 2784       0     300       0     150     300     200     400     300       0
# ...

# %%
# E
dfE_negative = df.loc[(df["品項"] == "E") & (df["店家代號"].isin(["742"]))]
dfE_negative
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 3743  E  742       0       0     200       0       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 3743       0      60      20       0     200       0       0       0     500
#
#      2021/09 2021/10 2021/11 2021/12
# 3743       0       0       0       0

# %%
# F 新品,2021年1-8月沒賣,無法比較

# %%
# G 新品,2021年1-8月沒賣,無法比較

# %%
# H 新品,2021年1-8月沒賣,無法比較

# %% [markdown]
# ## 正成長

# %%
# A
dfA_positive  = df.loc[(df["品項"] == "A") & (df["店家代號"].isin(["304","745","789","782","829","795"]))]
dfA_positive
# Out:
#     品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 306  A  304      20     310     170    1050       0       0     100      30
# 747  A  745     180     550     200    1200       0       0      10       0
# 784  A  782       0      60     145     300       0      30     120      60
# 791  A  789      69      99      38     246       0       0      55       0
# 797  A  795     120      40     160    1410       0       0       0       0
# 831  A  829       0       0      30    1947    -967       0       0       0
#
#     2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 306      40       0       0       0      50       0       0       0       0
# 747       0       0       0       0     600     200     400     400       0
# 784      60       0       0       0       0       0      10       0     110
# 791       0       0       0       0       0       0       0       0      70
# ...

# %%
# B
dfB_positive  = df.loc[(df["品項"] == "B") & (df["店家代號"].isin(["159","304","430","749","829","795"]))]
dfB_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 1065  B  159      85      30     100     450       0     180       0       0
# 1206  B  304       0     260     110    1090       0       0       0       0
# 1330  B  430      40       5     565     545       0      30      66      90
# 1629  B  749       0     100       0     600       0       0       0       0
# 1670  B  795     100      30     130    1330       0       0       0       0
# 1700  B  829       0       0       0    1618    -768       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 1065       0       0       0       0       0      55     250       0       0
# 1206      10       0       0       0      30      10       0       0       0
# 1330      20      10      12      10      30      64      50       0      70
# 1629       0       0       0       0       0       0       0     200       0
# ...

# %%
# C
dfC_positive  = df.loc[(df["品項"] == "C") & (df["店家代號"].isin(["304","749","782","795"]))]
dfC_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 2108  C  304      30     210      50     527       0       0     100      60
# 2539  C  749       0     100       0     600       0       0       0       0
# 2571  C  782       0      70     120     230       0     120      40      50
# 2583  C  795     110      40     150    1460       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 2108      60       0       0       0      30      20       0       0       0
# 2539       0       0       0       0       0       0       0     200       0
# 2571      50       0       0       0       0       0      10       0     110
# 2583       0       0       0       0       0       0       0       0       0
#
#      2021/09 2021/10 2021/11 2021/12
# 2108       0       0       0       0
# 2539       0       0       0       0
# 2571       0       0     100      80
# 2583       0     100     140     100

# %%
# D
dfD_positive = df.loc[(df["品項"] == "D") & (df["店家代號"].isin(["159","304","688","749","782","795"]))]
dfD_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 2850  D  159      60      20      50     330       0       0       0       0
# 2986  D  304       0     210      50     250       0       0       0       0
# 3338  D  688       0       0       0     480       0       0       0       0
# 3392  D  749      30     100       0     600       0       0       0       0
# 3421  D  782       0      30      80     100      40      30      50      10
# 3433  D  795      80      20      90    1100       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 2850       0       0       0       0      40      30     130       0       0
# 2986      10       0       0       0      10      10       0       0       0
# 3338       0       0      10       0      40      10     120      30       0
# 3392       0       0       0       0     200       0     200     100       0
# ...

# %%
# E
dfE_positive = df.loc[(df["品項"] == "E") & (df["店家代號"].isin(["540","743"]))]
dfE_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 3693  E  540       0       0      30     400       0      30       0       0
# 3744  E  743       0       0       0     400       0       0       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 3693       0      20       5      10      60      30       0       0      80
# 3744       0       0       0     110       0     100       0       0       0
#
#      2021/09 2021/10 2021/11 2021/12
# 3693       0       0       0       0
# 3744       0       0       0       0

# %%
# F
dfF_positive = df.loc[(df["品項"] == "F") & (df["店家代號"].isin(["29","130","292","304","499","534","743","795","696"]))]
dfF_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 3815  F   29      10       0       0       0       0      30      50      15
# 3865  F  130       0       0      10      10      25       0      40      30
# 3965  F  292      20      20       0      20      25       0      25       0
# 3973  F  304       0       0       0      30       5     240       0      25
# 4084  F  499       0       0      70       0       0      10       0      25
# 4101  F  534       0      23       2      43      25       0      55       0
# 4178  F  696       0      20       0      10       0      65      25     240
# 4208  F  743       0       0       0       0       0      85       0      25
# 4235  F  795       0       0      10      60       0       0       0      60
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 3815       0       0       0       0       0       0       0       0       0
# ...

# %%
# G
dfG_positive = df.loc[(df["品項"] == "G") & (df["店家代號"].isin(["6","7","57","130","251","362","482","534","742","743","745","795","806"]))]
dfG_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 4363  G    6       0       0      30     130      50       0      45       0
# 4364  G    7       0       0     100      40      20       0      95       0
# 4399  G   57       0       0      10      60      30       0      50       0
# 4439  G  130       0       0      20      70     120       0     100       0
# 4519  G  251       0       0      40      80      20       0      90       0
# 4589  G  362       0       0      30      60      30       0      50       0
# 4671  G  482       0       0      69      30      36       0      50       0
# 4696  G  534       0       0      47     107      20       0      21       0
# 4814  G  742       0       0     200     200      45       0      30       0
# 4815  G  743       0       0     200       0       0       0       0       0
# 4817  G  745       0       0      20      40      50       0      40       0
# ...

# %%
# H 
dfH_positive = df.loc[(df["品項"] == "H") & (df["店家代號"].isin(["6","7","130","414","482","696","742","743"]))]
dfH_positive
# Out:
#      品項 店家代號 2022/01 2022/02 2022/03 2022/04 2022/05 2022/06 2022/07 2022/08  \
# 4967  H    6       0       0       0      26       0      10       0      37
# 4968  H    7       0      20       0       0       0      22      10      20
# 5021  H  130      10      10      10       0      35      10      10       0
# 5144  H  414      10      10      10      10       0      15       5       0
# 5178  H  482      10       0      15      10       5       5       0       5
# 5261  H  696       0       0       0       0       0      10       0      40
# 5284  H  742       0       0       0       0       5      18       0      40
# 5285  H  743       0       0       0     100       0      65       0       0
#
#      2022/09 2021/01 2021/02 2021/03 2021/04 2021/05 2021/06 2021/07 2021/08  \
# 4967       0       0       0       0       0       0       0       0       0
# 4968       5       0       0       0       0       0       0       0       0
# ...
